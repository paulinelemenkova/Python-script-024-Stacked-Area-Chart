# %%
# library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.chdir('/Users/pauline/Documents/Python')
df = pd.read_csv("Tab-Morph.csv")
#df.head(5)
 
# Your x and y axis
x=df.profile
y=[ df.Min, df.Mean, df.Median, df.Max ]
# Dataset

pal = sns.color_palette("ocean")
plt.stackplot(x,y, labels=['Min','Mean','Median', 'Max'], colors=pal, alpha=0.4 )
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Stacked area chart for the Mariana Trench bathymetry: \ndepths by 25 cross-section profiles', 
          fontsize=12, fontfamily='serif')

plt.show()
